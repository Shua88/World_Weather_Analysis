# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 763

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):

    #if you want to run just a few lines can do enumerate(cities[:5]):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        #city_weather_description needs the brackets and 0 because it is a list, unlike the others which are just dictionaries
        
        # Append the city information into the city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | uzunovo
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | egvekinot
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | adre
# Processing Record 7 of Set 1 | half moon bay
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | oranjestad
# Processing Record 10 of Set 1 | bengkulu
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | korla
# Processing Record 13 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | salinopolis
# Processing Record 16 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | voronovytsya
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | high prairie
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | ahipara
# Processing Record 26 of Set 1 | faanui
# Processing Record 27 of Set 1 | sitka
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | gizo
# Processing Record 30 of Set 1 | tera
# Processing Record 31 of Set 1 | makakilo city
# Processing Record 32 of Set 1 | san vicente
# Processing Record 33 of Set 1 | marsh harbour
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | rio grande
# Processing Record 36 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | kirensk
# Processing Record 39 of Set 1 | chokurdakh
# Processing Record 40 of Set 1 | cayenne
# Processing Record 41 of Set 1 | coquimbo
# Processing Record 42 of Set 1 | buala
# Processing Record 43 of Set 1 | misratah
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | kamenka
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | viransehir
# Processing Record 48 of Set 1 | nyurba
# Processing Record 49 of Set 1 | port hedland
# Processing Record 50 of Set 1 | kodiak
# Processing Record 1 of Set 2 | kolomak
# Processing Record 2 of Set 2 | aden
# Processing Record 3 of Set 2 | esperance
# Processing Record 4 of Set 2 | namatanai
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | karlstad
# Processing Record 7 of Set 2 | panorama
# Processing Record 8 of Set 2 | tokur
# Processing Record 9 of Set 2 | singkawang
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | minador do negrao
# Processing Record 12 of Set 2 | constitucion
# Processing Record 13 of Set 2 | raudeberg
# Processing Record 14 of Set 2 | fort nelson
# Processing Record 15 of Set 2 | urucara
# Processing Record 16 of Set 2 | chaplynka
# Processing Record 17 of Set 2 | penzance
# Processing Record 18 of Set 2 | provideniya
# Processing Record 19 of Set 2 | lahij
# Processing Record 20 of Set 2 | carnarvon
# Processing Record 21 of Set 2 | srednekolymsk
# Processing Record 22 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 2 | garango
# Processing Record 24 of Set 2 | tiksi
# Processing Record 25 of Set 2 | nacimiento
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 2 | katsuura
# Processing Record 29 of Set 2 | concepcion
# Processing Record 30 of Set 2 | roma
# Processing Record 31 of Set 2 | ajdabiya
# Processing Record 32 of Set 2 | olga
# Processing Record 33 of Set 2 | igarka
# Processing Record 34 of Set 2 | harper
# Processing Record 35 of Set 2 | thap than
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | north bend
# Processing Record 39 of Set 2 | leningradskiy
# Processing Record 40 of Set 2 | acarau
# Processing Record 41 of Set 2 | severo-kurilsk
# Processing Record 42 of Set 2 | bambous virieux
# Processing Record 43 of Set 2 | gorebridge
# Processing Record 44 of Set 2 | ipero
# Processing Record 45 of Set 2 | new norfolk
# Processing Record 46 of Set 2 | vao
# Processing Record 47 of Set 2 | imbituba
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | wahiawa
# Processing Record 1 of Set 3 | norman wells
# Processing Record 2 of Set 3 | kamogawa
# Processing Record 3 of Set 3 | hobart
# Processing Record 4 of Set 3 | tazovskiy
# Processing Record 5 of Set 3 | wolfville
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | weinan
# Processing Record 8 of Set 3 | saint george
# Processing Record 9 of Set 3 | clyde river
# Processing Record 10 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 3 | santa maria
# Processing Record 12 of Set 3 | abha
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | lebu
# Processing Record 15 of Set 3 | tete
# Processing Record 16 of Set 3 | boyolangu
# Processing Record 17 of Set 3 | djougou
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | krasnyy chikoy
# Processing Record 20 of Set 3 | kutum
# Processing Record 21 of Set 3 | terrace
# Processing Record 22 of Set 3 | arraial do cabo
# Processing Record 23 of Set 3 | bredasdorp
# Processing Record 24 of Set 3 | berlevag
# Processing Record 25 of Set 3 | pangai
# Processing Record 26 of Set 3 | vila do maio
# Processing Record 27 of Set 3 | souillac
# Processing Record 28 of Set 3 | kuldur
# Processing Record 29 of Set 3 | orissaare
# Processing Record 30 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | ambilobe
# Processing Record 33 of Set 3 | lucapa
# Processing Record 34 of Set 3 | vila velha
# Processing Record 35 of Set 3 | praia
# Processing Record 36 of Set 3 | sydney
# Processing Record 37 of Set 3 | brae
# Processing Record 38 of Set 3 | mahebourg
# Processing Record 39 of Set 3 | saskylakh
# Processing Record 40 of Set 3 | matagami
# Processing Record 41 of Set 3 | poum
# Processing Record 42 of Set 3 | bethel
# Processing Record 43 of Set 3 | sawakin
# Processing Record 44 of Set 3 | yima
# Processing Record 45 of Set 3 | george town
# Processing Record 46 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 47 of Set 3 | pangoa
# Processing Record 48 of Set 3 | kinshasa
# Processing Record 49 of Set 3 | karaman
# Processing Record 50 of Set 3 | maun
# Processing Record 1 of Set 4 | kapit
# Processing Record 2 of Set 4 | victoria
# Processing Record 3 of Set 4 | chumikan
# Processing Record 4 of Set 4 | the valley
# Processing Record 5 of Set 4 | aykino
# Processing Record 6 of Set 4 | beringovskiy
# Processing Record 7 of Set 4 | hualmay
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | verkh-usugli
# Processing Record 10 of Set 4 | vilyuysk
# Processing Record 11 of Set 4 | hagere hiywet
# Processing Record 12 of Set 4 | kawhia
# Processing Record 13 of Set 4 | houma
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 4 | pascagoula
# Processing Record 17 of Set 4 | rocha
# Processing Record 18 of Set 4 | selma
# Processing Record 19 of Set 4 | rawson
# Processing Record 20 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 4 | youghal
# Processing Record 22 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 4 | southbridge
# Processing Record 24 of Set 4 | high level
# Processing Record 25 of Set 4 | tasiilaq
# Processing Record 26 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 4 | samarai
# Processing Record 28 of Set 4 | puerto ayora
# Processing Record 29 of Set 4 | sisimiut
# Processing Record 30 of Set 4 | vysokogornyy
# Processing Record 31 of Set 4 | hirado
# Processing Record 32 of Set 4 | luton
# Processing Record 33 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 4 | pacific grove
# Processing Record 35 of Set 4 | dikson
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | huangzhou
# Processing Record 38 of Set 4 | uvira
# Processing Record 39 of Set 4 | ivajlovgrad
# City not found. Skipping...
# Processing Record 40 of Set 4 | hervey bay
# Processing Record 41 of Set 4 | seoul
# Processing Record 42 of Set 4 | djambala
# Processing Record 43 of Set 4 | san patricio
# Processing Record 44 of Set 4 | kavieng
# Processing Record 45 of Set 4 | lang son
# Processing Record 46 of Set 4 | talnakh
# Processing Record 47 of Set 4 | nyaunglebin
# Processing Record 48 of Set 4 | trinidad
# Processing Record 49 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 50 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 5 | kaitangata
# Processing Record 2 of Set 5 | khovu-aksy
# Processing Record 3 of Set 5 | jamestown
# Processing Record 4 of Set 5 | lloydminster
# Processing Record 5 of Set 5 | faya
# Processing Record 6 of Set 5 | naze
# Processing Record 7 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 5 | marana
# Processing Record 9 of Set 5 | raychikhinsk
# Processing Record 10 of Set 5 | portland
# Processing Record 11 of Set 5 | fortuna
# Processing Record 12 of Set 5 | nurota
# Processing Record 13 of Set 5 | oranjemund
# Processing Record 14 of Set 5 | whitehorse
# Processing Record 15 of Set 5 | yulara
# Processing Record 16 of Set 5 | torbay
# Processing Record 17 of Set 5 | avarua
# Processing Record 18 of Set 5 | lavrentiya
# Processing Record 19 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 5 | santa cruz de la palma
# Processing Record 21 of Set 5 | neiafu
# Processing Record 22 of Set 5 | east london
# Processing Record 23 of Set 5 | baijiantan
# Processing Record 24 of Set 5 | abashiri
# Processing Record 25 of Set 5 | kahului
# Processing Record 26 of Set 5 | phimai
# Processing Record 27 of Set 5 | moranbah
# Processing Record 28 of Set 5 | akyab
# Processing Record 29 of Set 5 | georgetown
# Processing Record 30 of Set 5 | ponta do sol
# Processing Record 31 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 32 of Set 5 | kinablangan
# Processing Record 33 of Set 5 | kulhudhuffushi
# Processing Record 34 of Set 5 | cherskiy
# Processing Record 35 of Set 5 | talgram
# Processing Record 36 of Set 5 | kalmar
# Processing Record 37 of Set 5 | guerrero negro
# Processing Record 38 of Set 5 | deputatskiy
# Processing Record 39 of Set 5 | buedu
# Processing Record 40 of Set 5 | padang
# Processing Record 41 of Set 5 | sayyan
# Processing Record 42 of Set 5 | atar
# Processing Record 43 of Set 5 | mariental
# Processing Record 44 of Set 5 | normandin
# Processing Record 45 of Set 5 | benguela
# Processing Record 46 of Set 5 | kismayo
# Processing Record 47 of Set 5 | grindavik
# Processing Record 48 of Set 5 | sao francisco
# Processing Record 49 of Set 5 | nizhniy baskunchak
# Processing Record 50 of Set 5 | alofi
# Processing Record 1 of Set 6 | namibe
# Processing Record 2 of Set 6 | bara
# Processing Record 3 of Set 6 | gazojak
# Processing Record 4 of Set 6 | komsomolskiy
# Processing Record 5 of Set 6 | ibotirama
# Processing Record 6 of Set 6 | tuy hoa
# Processing Record 7 of Set 6 | lompoc
# Processing Record 8 of Set 6 | teguldet
# Processing Record 9 of Set 6 | barrow
# Processing Record 10 of Set 6 | auki
# Processing Record 11 of Set 6 | skeldon
# Processing Record 12 of Set 6 | karratha
# Processing Record 13 of Set 6 | gornopravdinsk
# Processing Record 14 of Set 6 | gat
# Processing Record 15 of Set 6 | jishou
# Processing Record 16 of Set 6 | klaksvik
# Processing Record 17 of Set 6 | popondetta
# Processing Record 18 of Set 6 | ossora
# Processing Record 19 of Set 6 | pundaguitan
# Processing Record 20 of Set 6 | meulaboh
# Processing Record 21 of Set 6 | luderitz
# Processing Record 22 of Set 6 | tevriz
# Processing Record 23 of Set 6 | longyearbyen
# Processing Record 24 of Set 6 | roald
# Processing Record 25 of Set 6 | hithadhoo
# Processing Record 26 of Set 6 | narsaq
# Processing Record 27 of Set 6 | smithers
# Processing Record 28 of Set 6 | keti bandar
# Processing Record 29 of Set 6 | huicungo
# Processing Record 30 of Set 6 | chatakonda
# Processing Record 31 of Set 6 | nuuk
# Processing Record 32 of Set 6 | vostok
# Processing Record 33 of Set 6 | lake cowichan
# Processing Record 34 of Set 6 | pevek
# Processing Record 35 of Set 6 | badovinci
# Processing Record 36 of Set 6 | margate
# Processing Record 37 of Set 6 | ipixuna
# Processing Record 38 of Set 6 | vernon
# Processing Record 39 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 6 | nuristan
# Processing Record 41 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 6 | okhotsk
# Processing Record 43 of Set 6 | kavaratti
# Processing Record 44 of Set 6 | shitkino
# Processing Record 45 of Set 6 | yar-sale
# Processing Record 46 of Set 6 | kanigiri
# Processing Record 47 of Set 6 | mtwara
# Processing Record 48 of Set 6 | hanyang
# Processing Record 49 of Set 6 | bose
# Processing Record 50 of Set 6 | mnogovershinnyy
# Processing Record 1 of Set 7 | tabou
# Processing Record 2 of Set 7 | hoi an
# Processing Record 3 of Set 7 | port-gentil
# Processing Record 4 of Set 7 | sabha
# Processing Record 5 of Set 7 | cairns
# Processing Record 6 of Set 7 | mombetsu
# Processing Record 7 of Set 7 | sur
# Processing Record 8 of Set 7 | dothan
# Processing Record 9 of Set 7 | darab
# Processing Record 10 of Set 7 | ode
# Processing Record 11 of Set 7 | monforte de lemos
# Processing Record 12 of Set 7 | diamantino
# Processing Record 13 of Set 7 | hovd
# Processing Record 14 of Set 7 | niksic
# Processing Record 15 of Set 7 | port hardy
# Processing Record 16 of Set 7 | khorramshahr
# Processing Record 17 of Set 7 | derbent
# Processing Record 18 of Set 7 | darnah
# Processing Record 19 of Set 7 | verkhnevilyuysk
# Processing Record 20 of Set 7 | husavik
# Processing Record 21 of Set 7 | la ronge
# Processing Record 22 of Set 7 | rio gallegos
# Processing Record 23 of Set 7 | minyar
# Processing Record 24 of Set 7 | blackfoot
# Processing Record 25 of Set 7 | severo-yeniseyskiy
# Processing Record 26 of Set 7 | brighton
# Processing Record 27 of Set 7 | ellensburg
# Processing Record 28 of Set 7 | shunyi
# Processing Record 29 of Set 7 | aykhal
# Processing Record 30 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 31 of Set 7 | vilhena
# Processing Record 32 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 33 of Set 7 | christiansburg
# Processing Record 34 of Set 7 | sigerfjord
# City not found. Skipping...
# Processing Record 35 of Set 7 | kamaishi
# Processing Record 36 of Set 7 | acari
# Processing Record 37 of Set 7 | ribeira grande
# Processing Record 38 of Set 7 | chuy
# Processing Record 39 of Set 7 | bernalillo
# Processing Record 40 of Set 7 | upernavik
# Processing Record 41 of Set 7 | ampanihy
# Processing Record 42 of Set 7 | mandurah
# Processing Record 43 of Set 7 | honningsvag
# Processing Record 44 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 7 | laurel
# Processing Record 46 of Set 7 | darhan
# Processing Record 47 of Set 7 | banjar
# Processing Record 48 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 7 | katherine
# Processing Record 50 of Set 7 | kununurra
# Processing Record 1 of Set 8 | pangnirtung
# Processing Record 2 of Set 8 | nanortalik
# Processing Record 3 of Set 8 | guanica
# Processing Record 4 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 5 of Set 8 | paoua
# Processing Record 6 of Set 8 | taltal
# Processing Record 7 of Set 8 | agadir
# Processing Record 8 of Set 8 | fairbanks
# Processing Record 9 of Set 8 | arlit
# Processing Record 10 of Set 8 | placido de castro
# Processing Record 11 of Set 8 | lorengau
# Processing Record 12 of Set 8 | ponta pora
# Processing Record 13 of Set 8 | chicama
# Processing Record 14 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 8 | osmena
# Processing Record 16 of Set 8 | ojinaga
# Processing Record 17 of Set 8 | sao joao da barra
# Processing Record 18 of Set 8 | sungaipenuh
# Processing Record 19 of Set 8 | kyra
# Processing Record 20 of Set 8 | praya
# Processing Record 21 of Set 8 | holme
# Processing Record 22 of Set 8 | bodden town
# Processing Record 23 of Set 8 | lianran
# Processing Record 24 of Set 8 | nouakchott
# Processing Record 25 of Set 8 | carahue
# Processing Record 26 of Set 8 | walvis bay
# Processing Record 27 of Set 8 | dicabisagan
# Processing Record 28 of Set 8 | qaqortoq
# Processing Record 29 of Set 8 | satellite beach
# Processing Record 30 of Set 8 | ilorin
# Processing Record 31 of Set 8 | aklavik
# Processing Record 32 of Set 8 | urumqi
# Processing Record 33 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 34 of Set 8 | yerbogachen
# Processing Record 35 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 8 | andros town
# Processing Record 37 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 8 | mattru
# Processing Record 39 of Set 8 | missoula
# Processing Record 40 of Set 8 | hofn
# Processing Record 41 of Set 8 | hasaki
# Processing Record 42 of Set 8 | bolshiye uki
# City not found. Skipping...
# Processing Record 43 of Set 8 | iki-burul
# Processing Record 44 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 8 | el alto
# Processing Record 48 of Set 8 | pasir gudang
# Processing Record 49 of Set 8 | luganville
# Processing Record 50 of Set 8 | synya
# Processing Record 1 of Set 9 | sosnogorsk
# Processing Record 2 of Set 9 | brookings
# Processing Record 3 of Set 9 | wangaratta
# Processing Record 4 of Set 9 | labuhan
# Processing Record 5 of Set 9 | brookhaven
# Processing Record 6 of Set 9 | kodinsk
# Processing Record 7 of Set 9 | salalah
# Processing Record 8 of Set 9 | casper
# Processing Record 9 of Set 9 | sidney
# Processing Record 10 of Set 9 | mormugao
# Processing Record 11 of Set 9 | kuusamo
# Processing Record 12 of Set 9 | mayo
# Processing Record 13 of Set 9 | yeppoon
# Processing Record 14 of Set 9 | ambon
# Processing Record 15 of Set 9 | thompson
# Processing Record 16 of Set 9 | muros
# Processing Record 17 of Set 9 | pundri
# Processing Record 18 of Set 9 | campbell river
# Processing Record 19 of Set 9 | lasa
# Processing Record 20 of Set 9 | saint-joseph
# Processing Record 21 of Set 9 | hohhot
# Processing Record 22 of Set 9 | bathsheba
# Processing Record 23 of Set 9 | ilheus
# Processing Record 24 of Set 9 | eureka
# Processing Record 25 of Set 9 | kilkenny
# Processing Record 26 of Set 9 | galveston
# Processing Record 27 of Set 9 | caravelas
# Processing Record 28 of Set 9 | comodoro rivadavia
# Processing Record 29 of Set 9 | san policarpo
# Processing Record 30 of Set 9 | laguna
# Processing Record 31 of Set 9 | ahuimanu
# Processing Record 32 of Set 9 | palm bay
# Processing Record 33 of Set 9 | waounde
# Processing Record 34 of Set 9 | flinders
# Processing Record 35 of Set 9 | benito juarez
# Processing Record 36 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 9 | iberia
# Processing Record 38 of Set 9 | paamiut
# Processing Record 39 of Set 9 | saint-georges
# Processing Record 40 of Set 9 | zharkent
# Processing Record 41 of Set 9 | ostrovnoy
# Processing Record 42 of Set 9 | villazon
# Processing Record 43 of Set 9 | sao filipe
# Processing Record 44 of Set 9 | petushki
# Processing Record 45 of Set 9 | fujin
# Processing Record 46 of Set 9 | hambantota
# Processing Record 47 of Set 9 | tigil
# Processing Record 48 of Set 9 | omaruru
# Processing Record 49 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 9 | asau
# Processing Record 1 of Set 10 | dingle
# Processing Record 2 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 10 | beruni
# City not found. Skipping...
# Processing Record 4 of Set 10 | zhanaozen
# Processing Record 5 of Set 10 | taoudenni
# Processing Record 6 of Set 10 | grand gaube
# Processing Record 7 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 8 of Set 10 | pachperwa
# Processing Record 9 of Set 10 | san pedro
# Processing Record 10 of Set 10 | lata
# Processing Record 11 of Set 10 | sorong
# Processing Record 12 of Set 10 | havelock
# Processing Record 13 of Set 10 | caloundra
# Processing Record 14 of Set 10 | abu samrah
# Processing Record 15 of Set 10 | agde
# Processing Record 16 of Set 10 | kidal
# Processing Record 17 of Set 10 | nur
# Processing Record 18 of Set 10 | gazanjyk
# Processing Record 19 of Set 10 | labrea
# Processing Record 20 of Set 10 | sorland
# Processing Record 21 of Set 10 | yara
# Processing Record 22 of Set 10 | mogadishu
# Processing Record 23 of Set 10 | general roca
# Processing Record 24 of Set 10 | honolulu
# Processing Record 25 of Set 10 | mehamn
# Processing Record 26 of Set 10 | ouadda
# Processing Record 27 of Set 10 | goderich
# Processing Record 28 of Set 10 | sabang
# Processing Record 29 of Set 10 | tabas
# Processing Record 30 of Set 10 | pisco
# Processing Record 31 of Set 10 | marawi
# Processing Record 32 of Set 10 | rokytne
# Processing Record 33 of Set 10 | velykoploske
# Processing Record 34 of Set 10 | geraldton
# Processing Record 35 of Set 10 | ancud
# Processing Record 36 of Set 10 | novopskov
# Processing Record 37 of Set 10 | honiara
# Processing Record 38 of Set 10 | nouadhibou
# Processing Record 39 of Set 10 | vangaindrano
# Processing Record 40 of Set 10 | kota belud
# Processing Record 41 of Set 10 | novopokrovka
# Processing Record 42 of Set 10 | najran
# Processing Record 43 of Set 10 | tupik
# Processing Record 44 of Set 10 | stubbekobing
# Processing Record 45 of Set 10 | chiang klang
# Processing Record 46 of Set 10 | moree
# Processing Record 47 of Set 10 | peskovka
# Processing Record 48 of Set 10 | uarini
# Processing Record 49 of Set 10 | bjornevatn
# Processing Record 50 of Set 10 | kannur
# Processing Record 1 of Set 11 | korocha
# Processing Record 2 of Set 11 | port lincoln
# Processing Record 3 of Set 11 | sept-iles
# Processing Record 4 of Set 11 | belogorsk
# Processing Record 5 of Set 11 | sistranda
# Processing Record 6 of Set 11 | dakar
# Processing Record 7 of Set 11 | college
# Processing Record 8 of Set 11 | nanakuli
# Processing Record 9 of Set 11 | rolla
# Processing Record 10 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 11 | sola
# Processing Record 12 of Set 11 | kopayhorod
# Processing Record 13 of Set 11 | plettenberg bay
# Processing Record 14 of Set 11 | aketi
# Processing Record 15 of Set 11 | nelson bay
# Processing Record 16 of Set 11 | kiomboi
# Processing Record 17 of Set 11 | guilin
# Processing Record 18 of Set 11 | moron
# Processing Record 19 of Set 11 | ulaanbaatar
# Processing Record 20 of Set 11 | hashtrud
# Processing Record 21 of Set 11 | hailar
# Processing Record 22 of Set 11 | saint-pierre
# Processing Record 23 of Set 11 | sinnamary
# Processing Record 24 of Set 11 | tautira
# Processing Record 25 of Set 11 | yumen
# Processing Record 26 of Set 11 | celestun
# Processing Record 27 of Set 11 | katobu
# Processing Record 28 of Set 11 | mandiana
# Processing Record 29 of Set 11 | pontes e lacerda
# Processing Record 30 of Set 11 | iraucuba
# Processing Record 31 of Set 11 | esna
# Processing Record 32 of Set 11 | zhigansk
# Processing Record 33 of Set 11 | calnic
# Processing Record 34 of Set 11 | rosenberg
# Processing Record 35 of Set 11 | bubaque
# Processing Record 36 of Set 11 | catamarca
# Processing Record 37 of Set 11 | khani
# Processing Record 38 of Set 11 | airai
# Processing Record 39 of Set 11 | christchurch
# Processing Record 40 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 11 | bulgan
# Processing Record 42 of Set 11 | codrington
# Processing Record 43 of Set 11 | vila franca do campo
# Processing Record 44 of Set 11 | riyadh
# Processing Record 45 of Set 11 | marsabit
# Processing Record 46 of Set 11 | noumea
# Processing Record 47 of Set 11 | moussoro
# Processing Record 48 of Set 11 | burica
# City not found. Skipping...
# Processing Record 49 of Set 11 | voyvozh
# Processing Record 50 of Set 11 | rockingham
# Processing Record 1 of Set 12 | khandbari
# Processing Record 2 of Set 12 | saint-augustin
# Processing Record 3 of Set 12 | natal
# Processing Record 4 of Set 12 | aleksandrov gay
# Processing Record 5 of Set 12 | kattivakkam
# Processing Record 6 of Set 12 | ternate
# Processing Record 7 of Set 12 | agva
# City not found. Skipping...
# Processing Record 8 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 9 of Set 12 | chiredzi
# Processing Record 10 of Set 12 | copiapo
# Processing Record 11 of Set 12 | santa cruz
# Processing Record 12 of Set 12 | carutapera
# Processing Record 13 of Set 12 | fallon
# Processing Record 14 of Set 12 | chaman
# Processing Record 15 of Set 12 | oktyabrskoye
# Processing Record 16 of Set 12 | guanare
# Processing Record 17 of Set 12 | tucuman
# Processing Record 18 of Set 12 | tadine
# Processing Record 19 of Set 12 | grootfontein
# Processing Record 20 of Set 12 | goure
# Processing Record 21 of Set 12 | assiniboia
# Processing Record 22 of Set 12 | sovetskiy
# Processing Record 23 of Set 12 | syumsi
# Processing Record 24 of Set 12 | tambacounda
# Processing Record 25 of Set 12 | piney green
# Processing Record 26 of Set 12 | araouane
# Processing Record 27 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 12 | adrar
# Processing Record 29 of Set 12 | namie
# Processing Record 30 of Set 12 | batticaloa
# Processing Record 31 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 12 | zatoka
# Processing Record 33 of Set 12 | vardo
# Processing Record 34 of Set 12 | oni
# Processing Record 35 of Set 12 | willmar
# Processing Record 36 of Set 12 | cleveland
# Processing Record 37 of Set 12 | san juan
# Processing Record 38 of Set 12 | tessalit
# Processing Record 39 of Set 12 | sinjar
# Processing Record 40 of Set 12 | paranavai
# Processing Record 41 of Set 12 | starokozache
# Processing Record 42 of Set 12 | dongsheng
# Processing Record 43 of Set 12 | inhambane
# Processing Record 44 of Set 12 | san rafael
# Processing Record 45 of Set 12 | coihaique
# Processing Record 46 of Set 12 | nabul
# City not found. Skipping...
# Processing Record 47 of Set 12 | ilulissat
# Processing Record 48 of Set 12 | shelopugino
# Processing Record 49 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 50 of Set 12 | haines junction
# Processing Record 1 of Set 13 | porto velho
# Processing Record 2 of Set 13 | mahajanga
# Processing Record 3 of Set 13 | roebourne
# Processing Record 4 of Set 13 | bondo
# Processing Record 5 of Set 13 | oktyabrskiy
# Processing Record 6 of Set 13 | lidingo
# Processing Record 7 of Set 13 | coruripe
# Processing Record 8 of Set 13 | middlebury
# Processing Record 9 of Set 13 | russell
# Processing Record 10 of Set 13 | shieli
# Processing Record 11 of Set 13 | cherat
# Processing Record 12 of Set 13 | creel
# Processing Record 13 of Set 13 | dumraon
# Processing Record 14 of Set 13 | newport
# Processing Record 15 of Set 13 | hay river
# Processing Record 16 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 17 of Set 13 | qui nhon
# Processing Record 18 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 13 | lakes entrance
# Processing Record 20 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 13 | manteca
# Processing Record 22 of Set 13 | broome
# Processing Record 23 of Set 13 | vaitape
# Processing Record 24 of Set 13 | petropavlovka
# Processing Record 25 of Set 13 | walla walla
# Processing Record 26 of Set 13 | le port
# Processing Record 27 of Set 13 | huaicheng
# Processing Record 28 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 29 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 30 of Set 13 | kichera
# Processing Record 31 of Set 13 | concordia
# Processing Record 32 of Set 13 | gudur
# Processing Record 33 of Set 13 | dauphin
# Processing Record 34 of Set 13 | gao
# Processing Record 35 of Set 13 | pittsburg
# Processing Record 36 of Set 13 | matara
# Processing Record 37 of Set 13 | saint-gaudens
# Processing Record 38 of Set 13 | beirut
# Processing Record 39 of Set 13 | dangriga
# Processing Record 40 of Set 13 | mayfield heights
# Processing Record 41 of Set 13 | mildura
# Processing Record 42 of Set 13 | cambridge
# Processing Record 43 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 44 of Set 13 | emerald
# Processing Record 45 of Set 13 | binghamton
# Processing Record 46 of Set 13 | sonoita
# Processing Record 47 of Set 13 | salacgriva
# Processing Record 48 of Set 13 | port macquarie
# Processing Record 49 of Set 13 | little current
# Processing Record 50 of Set 13 | riberalta
# Processing Record 1 of Set 14 | sabzevar
# Processing Record 2 of Set 14 | manicore
# Processing Record 3 of Set 14 | paita
# Processing Record 4 of Set 14 | podgorodnyaya pokrovka
# Processing Record 5 of Set 14 | kupang
# Processing Record 6 of Set 14 | sakaraha
# Processing Record 7 of Set 14 | richards bay
# Processing Record 8 of Set 14 | linhares
# Processing Record 9 of Set 14 | kampene
# Processing Record 10 of Set 14 | mount isa
# Processing Record 11 of Set 14 | razole
# Processing Record 12 of Set 14 | gamba
# Processing Record 13 of Set 14 | ixtapa
# Processing Record 14 of Set 14 | salmas
# Processing Record 15 of Set 14 | tilichiki
# Processing Record 16 of Set 14 | charters towers
# Processing Record 17 of Set 14 | urusha
# Processing Record 18 of Set 14 | los llanos de aridane
# Processing Record 19 of Set 14 | tavda
# Processing Record 20 of Set 14 | butembo
# Processing Record 21 of Set 14 | vaisala
# City not found. Skipping...
# Processing Record 22 of Set 14 | muisne
# Processing Record 23 of Set 14 | bada
# Processing Record 24 of Set 14 | sulangan
# Processing Record 25 of Set 14 | ottawa
# Processing Record 26 of Set 14 | waipawa
# Processing Record 27 of Set 14 | mayumba
# Processing Record 28 of Set 14 | petatlan
# Processing Record 29 of Set 14 | ozinki
# Processing Record 30 of Set 14 | dwarka
# Processing Record 31 of Set 14 | gasa
# Processing Record 32 of Set 14 | seminole
# Processing Record 33 of Set 14 | bonavista
# Processing Record 34 of Set 14 | puerto del rosario
# Processing Record 35 of Set 14 | rodrigues alves
# Processing Record 36 of Set 14 | aquiraz
# Processing Record 37 of Set 14 | camacha
# Processing Record 38 of Set 14 | henties bay
# Processing Record 39 of Set 14 | caapucu
# Processing Record 40 of Set 14 | pontianak
# Processing Record 41 of Set 14 | centralia
# Processing Record 42 of Set 14 | kudahuvadhoo
# Processing Record 43 of Set 14 | saint anthony
# Processing Record 44 of Set 14 | otradnoye
# Processing Record 45 of Set 14 | shimoda
# Processing Record 46 of Set 14 | patan
# Processing Record 47 of Set 14 | almazar
# Processing Record 48 of Set 14 | klamath falls
# Processing Record 49 of Set 14 | chaihe
# Processing Record 50 of Set 14 | svetlyy
# Processing Record 1 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 15 | jalu
# Processing Record 3 of Set 15 | katangli
# Processing Record 4 of Set 15 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 5 of Set 15 | zalantun
# Processing Record 6 of Set 15 | serchhip
# Processing Record 7 of Set 15 | visnes
# Processing Record 8 of Set 15 | barinas
# Processing Record 9 of Set 15 | jiazi
# Processing Record 10 of Set 15 | daru
# Processing Record 11 of Set 15 | san quintin
# Processing Record 12 of Set 15 | atlantic beach
# Processing Record 13 of Set 15 | tolaga bay
# Processing Record 14 of Set 15 | miles city
# Processing Record 15 of Set 15 | snasa
# Processing Record 16 of Set 15 | dudinka
# Processing Record 17 of Set 15 | vanimo
# Processing Record 18 of Set 15 | cristalina
# Processing Record 19 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 15 | avallon
# Processing Record 21 of Set 15 | ishurdi
# Processing Record 22 of Set 15 | krasnoselkup
# Processing Record 23 of Set 15 | isangel
# Processing Record 24 of Set 15 | skjervoy
# Processing Record 25 of Set 15 | nome
# Processing Record 26 of Set 15 | port hawkesbury
# Processing Record 27 of Set 15 | ankang
# Processing Record 28 of Set 15 | hamilton
# Processing Record 29 of Set 15 | rovaniemi
# Processing Record 30 of Set 15 | chimbote
# Processing Record 31 of Set 15 | olavarria
# Processing Record 32 of Set 15 | garissa
# Processing Record 33 of Set 15 | uruzgan
# Processing Record 34 of Set 15 | junction city
# Processing Record 35 of Set 15 | aljezur
# Processing Record 36 of Set 15 | san felipe
# Processing Record 37 of Set 15 | peniche
# Processing Record 38 of Set 15 | balkanabat
# Processing Record 39 of Set 15 | virginia beach
# Processing Record 40 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 15 | arauco
# Processing Record 42 of Set 15 | george
# Processing Record 43 of Set 15 | sabi
# Processing Record 44 of Set 15 | ramshir
# Processing Record 45 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 15 | nzerekore
# Processing Record 47 of Set 15 | ranong
# Processing Record 48 of Set 15 | kabelvag
# Processing Record 49 of Set 15 | grenville
# Processing Record 50 of Set 15 | lambarene
# Processing Record 1 of Set 16 | pyay
# Processing Record 2 of Set 16 | muscat
# Processing Record 3 of Set 16 | evensk
# Processing Record 4 of Set 16 | milingimbi
# City not found. Skipping...
# Processing Record 5 of Set 16 | price
# Processing Record 6 of Set 16 | charleston
# Processing Record 7 of Set 16 | mehran
# Processing Record 8 of Set 16 | burns lake
# Processing Record 9 of Set 16 | amberley
# Processing Record 10 of Set 16 | mackay
# Processing Record 11 of Set 16 | muriwai beach
# Processing Record 12 of Set 16 | roberval
# Processing Record 13 of Set 16 | diplo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 701

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         uzunovo  54.5386   38.6173     24.39        92         100
# 1  saint-philippe -21.3585   55.7679     85.59        72         100
# 2       egvekinot  66.3167 -179.1667    -10.53        85          11
# 3          castro -24.7911  -50.0119     63.91        98         100
# 4     yellowknife  62.4560 -114.3525     -8.45        77         100
# 5            adre  13.4667   22.2000     69.93        16           4
# 6   half moon bay  37.4636 -122.4286     58.10        87         100
# 7         rikitea -23.1203 -134.9692     78.08        73           0
# 8      oranjestad  12.5240  -70.0270     76.95        91          20
# 9        bengkulu  -3.8004  102.2655     83.37        67          99
#
#    Wind Speed Country          Weather
# 0       12.82      RU  overcast clouds
# 1       10.67      RE  overcast clouds
# 2       15.97      RU       few clouds
# 3        4.97      BR  overcast clouds
# 4       11.50      CA       light snow
# 5       14.20      TD        clear sky
# 6        9.22      US             mist
# 7       15.97      PF        clear sky
# 8       11.50      AW       few clouds
# 9        7.47      ID  overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_reorder = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Weather"]


#need to change the name of the column "weather" TOOOO "Current Description"

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_reorder]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         uzunovo      RU  54.5386   38.6173     24.39        92         100
# 1  saint-philippe      RE -21.3585   55.7679     85.59        72         100
# 2       egvekinot      RU  66.3167 -179.1667    -10.53        85          11
# 3          castro      BR -24.7911  -50.0119     63.91        98         100
# 4     yellowknife      CA  62.4560 -114.3525     -8.45        77         100
# 5            adre      TD  13.4667   22.2000     69.93        16           4
# 6   half moon bay      US  37.4636 -122.4286     58.10        87         100
# 7         rikitea      PF -23.1203 -134.9692     78.08        73           0
# 8      oranjestad      AW  12.5240  -70.0270     76.95        91          20
# 9        bengkulu      ID  -3.8004  102.2655     83.37        67          99
#
#    Wind Speed          Weather
# 0       12.82  overcast clouds
# 1       10.67  overcast clouds
# 2       15.97       few clouds
# 3        4.97  overcast clouds
# 4       11.50       light snow
# 5       14.20        clear sky
# 6        9.22             mist
# 7       15.97        clear sky
# 8       11.50       few clouds
# 9        7.47  overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Weather        object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
